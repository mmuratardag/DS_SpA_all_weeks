# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
df = pd.read_csv('TS_data.txt', sep=",", header=0)
df.head()
# Out:
#     SOUID      DATE   TG  Q_TG
# 0  128124  19470101  -24     0
# 1  128124  19470102  -35     0
# 2  128124  19470103  -45     0
# 3  128124  19470104 -127     0
# 4  128124  19470105 -150     0

# %%
df.dtypes
# Out:
# SOUID    int64
# DATE     int64
# TG       int64
# Q_TG     int64
# dtype: object

# %%
df['DATE'] = pd.to_datetime(df['DATE'].astype(str))
df.head()
#df.shape # (27060, 4)
# Out:
#     SOUID       DATE   TG  Q_TG
# 0  128124 1947-01-01  -24     0
# 1  128124 1947-01-02  -35     0
# 2  128124 1947-01-03  -45     0
# 3  128124 1947-01-04 -127     0
# 4  128124 1947-01-05 -150     0

# %%
df['TG'].replace(to_replace = -9999, value = np.nan, inplace=True)
#df.head()
df.shape # (27060, 4)
# Out:
# (27060, 4)

# %%
df.dropna(inplace=True)
#df.shape # (25964, 4)
df.head()
# Out:
#     SOUID       DATE     TG  Q_TG
# 0  128124 1947-01-01  -24.0     0
# 1  128124 1947-01-02  -35.0     0
# 2  128124 1947-01-03  -45.0     0
# 3  128124 1947-01-04 -127.0     0
# 4  128124 1947-01-05 -150.0     0

# %%
#df['TG'] = df['TG']*0.1
#df.head()

# %%
df.set_index('DATE', inplace=True)
df.head()
# Out:
#              SOUID     TG  Q_TG
# DATE
# 1947-01-01  128124  -24.0     0
# 1947-01-02  128124  -35.0     0
# 1947-01-03  128124  -45.0     0
# 1947-01-04  128124 -127.0     0
# 1947-01-05  128124 -150.0     0

# %%
df['January 1990':'December 2020']['TG'].plot(figsize=(20, 15));
# Out:
# <AxesSubplot:xlabel='DATE'>
