# %% [markdown]
# # 0) Warmup: Methods to join DataFrames in pandas

# %%
import pandas as pd

# %%
customers = pd.read_csv('northwind_data/customers.csv', index_col=0)
orders = pd.read_csv('northwind_data/orders.csv', index_col=0)

# %%
customers.head()
# Out:
#                                    companyName         contactName  \
# customerID
# ALFKI                      Alfreds Futterkiste        Maria Anders
# ANATR       Ana Trujillo Emparedados y helados        Ana Trujillo
# ANTON                  Antonio Moreno Taquería      Antonio Moreno
# AROUT                          Around the Horn        Thomas Hardy
# BERGS                       Berglunds snabbköp  Christina Berglund
#
#                     contactTitle                        address         city  \
# customerID
# ALFKI       Sales Representative                  Obere Str. 57       Berlin
# ANATR                      Owner  Avda. de la Constitución 2222  México D.F.
# ANTON                      Owner                Mataderos  2312  México D.F.
# AROUT       Sales Representative                120 Hanover Sq.       London
# BERGS        Order Administrator                Berguvsvägen  8        Luleå
#
#            region postalCode  country           phone             fax
# customerID
# ALFKI         NaN      12209  Germany     030-0074321     030-0076545
# ANATR         NaN      05021   Mexico    (5) 555-4729    (5) 555-3745
# ANTON         NaN      05023   Mexico    (5) 555-3932             NaN
# AROUT         NaN    WA1 1DP       UK  (171) 555-7788  (171) 555-6750
# BERGS         NaN   S-958 22   Sweden   0921-12 34 65   0921-12 34 67

# %%
# Use df.merge
orders.merge(customers, left_on='customerID', right_index=True).reset_index()
# Out:
#      orderID customerID  employeeID                orderDate  \
# 0      10248      VINET           5  1996-07-04 00:00:00.000
# 1      10274      VINET           6  1996-08-06 00:00:00.000
# 2      10295      VINET           2  1996-09-02 00:00:00.000
# 3      10737      VINET           2  1997-11-11 00:00:00.000
# 4      10739      VINET           3  1997-11-12 00:00:00.000
# ..       ...        ...         ...                      ...
# 825    11043      SPECD           5  1998-04-22 00:00:00.000
# 826    10858      LACOR           2  1998-01-29 00:00:00.000
# 827    10927      LACOR           4  1998-03-05 00:00:00.000
# 828    10972      LACOR           4  1998-03-24 00:00:00.000
# 829    10973      LACOR           6  1998-03-24 00:00:00.000
#
#                 requiredDate              shippedDate  shipVia  freight  \
# 0    1996-08-01 00:00:00.000  1996-07-16 00:00:00.000        3    32.38
# 1    1996-09-03 00:00:00.000  1996-08-16 00:00:00.000        1     6.01
# 2    1996-09-30 00:00:00.000  1996-09-10 00:00:00.000        2     1.15
# 3    1997-12-09 00:00:00.000  1997-11-18 00:00:00.000        2     7.79
# 4    1997-12-10 00:00:00.000  1997-11-17 00:00:00.000        3    11.08
# ..                       ...                      ...      ...      ...
# 825  1998-05-20 00:00:00.000  1998-04-29 00:00:00.000        2     8.80
# 826  1998-02-26 00:00:00.000  1998-02-03 00:00:00.000        1    52.51
# 827  1998-04-02 00:00:00.000  1998-04-08 00:00:00.000        1    19.79
# 828  1998-04-21 00:00:00.000  1998-03-26 00:00:00.000        2     0.02
# 829  1998-04-21 00:00:00.000  1998-03-27 00:00:00.000        2    15.17
#
#                       shipName            shipAddress  ...  \
# 0    Vins et alcools Chevalier     59 rue de l'Abbaye  ...
# 1    Vins et alcools Chevalier     59 rue de l'Abbaye  ...
# 2    Vins et alcools Chevalier     59 rue de l'Abbaye  ...
# 3    Vins et alcools Chevalier     59 rue de l'Abbaye  ...
# 4    Vins et alcools Chevalier     59 rue de l'Abbaye  ...
# ..                         ...                    ...  ...
# 825       Spécialités du monde       25 rue Lauriston  ...
# 826       La corne d'abondance  67 avenue de l'Europe  ...
# 827       La corne d'abondance  67 avenue de l'Europe  ...
# 828       La corne d'abondance  67 avenue de l'Europe  ...
# 829       La corne d'abondance  67 avenue de l'Europe  ...
#
#                    companyName        contactName          contactTitle  \
# 0    Vins et alcools Chevalier       Paul Henriot    Accounting Manager
# 1    Vins et alcools Chevalier       Paul Henriot    Accounting Manager
# 2    Vins et alcools Chevalier       Paul Henriot    Accounting Manager
# 3    Vins et alcools Chevalier       Paul Henriot    Accounting Manager
# 4    Vins et alcools Chevalier       Paul Henriot    Accounting Manager
# ..                         ...                ...                   ...
# 825       Spécialités du monde  Dominique Perrier     Marketing Manager
# 826       La corne d'abondance      Daniel Tonini  Sales Representative
# 827       La corne d'abondance      Daniel Tonini  Sales Representative
# 828       La corne d'abondance      Daniel Tonini  Sales Representative
# 829       La corne d'abondance      Daniel Tonini  Sales Representative
#
#                    address        city region postalCode country  \
# 0       59 rue de l'Abbaye       Reims    NaN      51100  France
# 1       59 rue de l'Abbaye       Reims    NaN      51100  France
# 2       59 rue de l'Abbaye       Reims    NaN      51100  France
# 3       59 rue de l'Abbaye       Reims    NaN      51100  France
# 4       59 rue de l'Abbaye       Reims    NaN      51100  France
# ..                     ...         ...    ...        ...     ...
# 825       25 rue Lauriston       Paris    NaN      75016  France
# 826  67 avenue de l'Europe  Versailles    NaN      78000  France
# 827  67 avenue de l'Europe  Versailles    NaN      78000  France
# 828  67 avenue de l'Europe  Versailles    NaN      78000  France
# 829  67 avenue de l'Europe  Versailles    NaN      78000  France
#
#                phone              fax
# 0        26.47.15.10      26.47.15.11
# 1        26.47.15.10      26.47.15.11
# 2        26.47.15.10      26.47.15.11
# 3        26.47.15.10      26.47.15.11
# 4        26.47.15.10      26.47.15.11
# ..               ...              ...
# 825  (1) 47.55.60.10  (1) 47.55.60.20
# 826      30.59.84.10      30.59.85.11
# 827      30.59.84.10      30.59.85.11
# 828      30.59.84.10      30.59.85.11
# 829      30.59.84.10      30.59.85.11
#
# [830 rows x 24 columns]

# %%
# Use df.join
orders.join(customers, on='customerID').reset_index()
# Out:
#      orderID customerID  employeeID                orderDate  \
# 0      10248      VINET           5  1996-07-04 00:00:00.000
# 1      10249      TOMSP           6  1996-07-05 00:00:00.000
# 2      10250      HANAR           4  1996-07-08 00:00:00.000
# 3      10251      VICTE           3  1996-07-08 00:00:00.000
# 4      10252      SUPRD           4  1996-07-09 00:00:00.000
# ..       ...        ...         ...                      ...
# 825    11073      PERIC           2  1998-05-05 00:00:00.000
# 826    11074      SIMOB           7  1998-05-06 00:00:00.000
# 827    11075      RICSU           8  1998-05-06 00:00:00.000
# 828    11076      BONAP           4  1998-05-06 00:00:00.000
# 829    11077      RATTC           1  1998-05-06 00:00:00.000
#
#                 requiredDate              shippedDate  shipVia  freight  \
# 0    1996-08-01 00:00:00.000  1996-07-16 00:00:00.000        3    32.38
# 1    1996-08-16 00:00:00.000  1996-07-10 00:00:00.000        1    11.61
# 2    1996-08-05 00:00:00.000  1996-07-12 00:00:00.000        2    65.83
# 3    1996-08-05 00:00:00.000  1996-07-15 00:00:00.000        1    41.34
# 4    1996-08-06 00:00:00.000  1996-07-11 00:00:00.000        2    51.30
# ..                       ...                      ...      ...      ...
# 825  1998-06-02 00:00:00.000                      NaN        2    24.95
# 826  1998-06-03 00:00:00.000                      NaN        2    18.44
# 827  1998-06-03 00:00:00.000                      NaN        2     6.19
# 828  1998-06-03 00:00:00.000                      NaN        2    38.28
# 829  1998-06-03 00:00:00.000                      NaN        2     8.53
#
#                        shipName               shipAddress  ...  \
# 0     Vins et alcools Chevalier        59 rue de l'Abbaye  ...
# 1            Toms Spezialitäten             Luisenstr. 48  ...
# 2                 Hanari Carnes            Rua do Paço 67  ...
# 3          Victuailles en stock         2 rue du Commerce  ...
# 4              Suprêmes délices       Boulevard Tirou 255  ...
# ..                          ...                       ...  ...
# 825   Pericles Comidas clásicas  Calle Dr. Jorge Cash 321  ...
# 826               Simons bistro              Vinbæltet 34  ...
# 827          Richter Supermarkt               Starenweg 5  ...
# 828                    Bon app'       12 rue des Bouchers  ...
# 829  Rattlesnake Canyon Grocery           2817 Milton Dr.  ...
#
#                     companyName          contactName  \
# 0     Vins et alcools Chevalier         Paul Henriot
# 1            Toms Spezialitäten        Karin Josephs
# 2                 Hanari Carnes         Mario Pontes
# 3          Victuailles en stock         Mary Saveley
# 4              Suprêmes délices     Pascale Cartrain
# ..                          ...                  ...
# 825   Pericles Comidas clásicas  Guillermo Fernández
# 826               Simons bistro       Jytte Petersen
# 827          Richter Supermarkt         Michael Holz
# 828                    Bon app'     Laurence Lebihan
# 829  Rattlesnake Canyon Grocery         Paula Wilson
#
#                        contactTitle                   address            city  \
# 0                Accounting Manager        59 rue de l'Abbaye           Reims
# 1                 Marketing Manager             Luisenstr. 48         Münster
# 2                Accounting Manager            Rua do Paço 67  Rio de Janeiro
# 3                       Sales Agent         2 rue du Commerce            Lyon
# 4                Accounting Manager       Boulevard Tirou 255       Charleroi
# ..                              ...                       ...             ...
# 825            Sales Representative  Calle Dr. Jorge Cash 321     México D.F.
# 826                           Owner              Vinbæltet 34       Kobenhavn
# 827                   Sales Manager         Grenzacherweg 237          Genève
# 828                           Owner       12 rue des Bouchers       Marseille
# 829  Assistant Sales Representative           2817 Milton Dr.     Albuquerque
#
#     region postalCode      country              phone                fax
# 0      NaN      51100       France        26.47.15.10        26.47.15.11
# 1      NaN      44087      Germany        0251-031259        0251-035695
# 2       RJ  05454-876       Brazil      (21) 555-0091      (21) 555-8765
# 3      NaN      69004       France        78.32.54.86        78.32.54.87
# 4      NaN     B-6000      Belgium  (071) 23 67 22 20  (071) 23 67 22 21
# ..     ...        ...          ...                ...                ...
# 825    NaN      05033       Mexico       (5) 552-3745       (5) 545-3745
# 826    NaN       1734      Denmark        31 12 34 56        31 13 35 57
# 827    NaN       1203  Switzerland        0897-034214                NaN
# 828    NaN      13008       France        91.24.45.40        91.24.45.41
# 829     NM      87110          USA     (505) 555-5939     (505) 555-3620
#
# [830 rows x 24 columns]

# %% [markdown]
# ### Install packages

# %%
# !pip install SQLAlchemy
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: SQLAlchemy in /Users/stefanroth/anaconda3/lib/python3.8/site-packages (1.3.20)
# Requirement already satisfied: psycopg2-binary in /Users/stefanroth/anaconda3/lib/python3.8/site-packages (2.8.6)

# %% [markdown]
# "SQLAlchemy is the Python SQL toolkit [...] that gives application developers the full power and flexibility of SQL." - https://www.sqlalchemy.org/

# %% [markdown]
# ### In order to connect to any database, we need 5 things:

# %%
from sqlalchemy import create_engine

# %% [markdown]
# 1. Host (i.e. IP address of the computer where the database server is installed / running)
# 2. Port Number (we set this up when we installed postgresql)
# 3. Username for Database server
# 4. Password for the Database Username
# 5. Name of the actual database inside the DB server.

# %%
import os

# %%
PASSWORD = os.getenv('DB_PASSWORD')

# %%
PASSWORD
# Out:
# '1234'

# %%
HOST = 'localhost'
PORT = '5432'
USERNAME = 'stefanroth'
DB = 'northwind'

# %% [markdown]
# Ideally you can set the PG_PASSWORD as an environment variable in your .bashrc file and use the below.

# %% [markdown]
# ### Create a "connection string", sort of like a URL.

# %%
conn_string = f'postgres://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DB}'

conn_string_mac = f'postgres://{HOST}:{PORT}/{DB}'

# %%
conn_string
# Out:
# 'postgres://stefanroth:None@localhost:5432/northwind'

# %% [markdown]
# ### Use the connection string with SQLAlchemy to connect to DB
#
# At this point you are only initialising the connection rather than starting it. It now is initialised for PostgresSQL usage and has a DBAPI that will connect to the actual database.

# %%
engine = create_engine(conn_string, echo=True)

# %%
engine
# Out:
# Engine(postgres://stefanroth:***@localhost:5432/northwind)

# %% [markdown]
# ### We can execute raw SQL query!

# %%
query = """
CREATE TABLE IF NOT EXISTS neworders2 (
col_1 VARCHAR(50),
col_2 INTEGER,
col_3 REAL
);
"""

# %% [markdown]
# Now we can actually execute queries

# %%
engine.execute(query)
# Out:
# 2021-02-11 14:12:03,951 INFO sqlalchemy.engine.base.Engine select version()
# 2021-02-11 14:12:03,952 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:12:03,953 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2021-02-11 14:12:03,953 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:12:03,955 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-02-11 14:12:03,956 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:12:03,958 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-02-11 14:12:03,958 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:12:03,960 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2021-02-11 14:12:03,960 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:12:03,961 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE IF NOT EXISTS neworders2 (
# col_1 VARCHAR(50),
# col_2 INTEGER,
# col_3 REAL
# );
#
# 2021-02-11 14:12:03,962 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:12:03,963 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# In the password error go and check your connection! We created to connections one with one without a password.

# %% [markdown]
# ### Combining this with Pandas

# %% [markdown]
# Instead of psql's \copy, we can use the pd.read_csv we are used to here.
#
# But I recommend at the moment that you can use this week to use the
# pswl as much as possible, to get familiar with it.

# %%
orders.head()
# Out:
#         customerID  employeeID                orderDate  \
# orderID
# 10248        VINET           5  1996-07-04 00:00:00.000
# 10249        TOMSP           6  1996-07-05 00:00:00.000
# 10250        HANAR           4  1996-07-08 00:00:00.000
# 10251        VICTE           3  1996-07-08 00:00:00.000
# 10252        SUPRD           4  1996-07-09 00:00:00.000
#
#                     requiredDate              shippedDate  shipVia  freight  \
# orderID
# 10248    1996-08-01 00:00:00.000  1996-07-16 00:00:00.000        3    32.38
# 10249    1996-08-16 00:00:00.000  1996-07-10 00:00:00.000        1    11.61
# 10250    1996-08-05 00:00:00.000  1996-07-12 00:00:00.000        2    65.83
# 10251    1996-08-05 00:00:00.000  1996-07-15 00:00:00.000        1    41.34
# 10252    1996-08-06 00:00:00.000  1996-07-11 00:00:00.000        2    51.30
#
#                           shipName          shipAddress        shipCity  \
# orderID
# 10248    Vins et alcools Chevalier   59 rue de l'Abbaye           Reims
# 10249           Toms Spezialitäten        Luisenstr. 48         Münster
# 10250                Hanari Carnes       Rua do Paço 67  Rio de Janeiro
# 10251         Victuailles en stock    2 rue du Commerce            Lyon
# 10252             Suprêmes délices  Boulevard Tirou 255       Charleroi
#
#         shipRegion shipPostalCode shipCountry
# orderID
# 10248          NaN          51100      France
# 10249          NaN          44087     Germany
# 10250           RJ      05454-876      Brazil
# 10251          NaN          69004      France
# 10252          NaN         B-6000     Belgium

# %%
type(orders)
# Out:
# pandas.core.frame.DataFrame

# %%
orders.dtypes
# Out:
# customerID         object
# employeeID          int64
# orderDate          object
# requiredDate       object
# shippedDate        object
# shipVia             int64
# freight           float64
# shipName           object
# shipAddress        object
# shipCity           object
# shipRegion         object
# shipPostalCode     object
# shipCountry        object
# dtype: object

# %% [markdown]
# Now write the modified table into the database as table_x... (a new relation).

# %%
from sqlalchemy import INT, TEXT, REAL

# %%
orders.to_sql(name='orders4', con=engine, if_exists='replace', dtype={'employeeID': REAL})

# %%
products = pd.read_sql_table('products', con=engine)
# Out:
# 2021-02-11 14:16:22,215 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-02-11 14:16:22,216 INFO sqlalchemy.engine.base.Engine {'schema': 'public'}
# 2021-02-11 14:16:22,218 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind IN ('v', 'm')
# 2021-02-11 14:16:22,219 INFO sqlalchemy.engine.base.Engine {'schema': 'public'}
# 2021-02-11 14:16:22,221 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-02-11 14:16:22,222 INFO sqlalchemy.engine.base.Engine {'table_name': 'products'}
# 2021-02-11 14:16:22,223 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-02-11 14:16:22,224 INFO sqlalchemy.engine.base.Engine {'table_oid': 16581}
# 2021-02-11 14:16:22,226 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-02-11 14:16:22,226 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:16:22,230 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-02-11 14:16:22,231 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:16:22,234 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-02-11 14:16:22,235 INFO sqlalchemy.engine.base.Engine {'table_oid': 16581}
# 2021-02-11 14:16:22,237 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-02-11 14:16:22,237 INFO sqlalchemy.engine.base.Engine {'table_oid': 16581}
# 2021-02-11 14:16:22,239 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2021-02-11 14:16:22,240 INFO sqlalchemy.engine.base.Engine {'table': 16581}
# 2021-02-11 14:16:22,246 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-02-11 14:16:22,247 INFO sqlalchemy.engine.base.Engine {'table_name': 'categories'}
# 2021-02-11 14:16:22,250 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-02-11 14:16:22,252 INFO sqlalchemy.engine.base.Engine {'table_oid': 16517}
# 2021-02-11 14:16:22,257 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-02-11 14:16:22,258 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:16:22,263 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-02-11 14:16:22,264 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:16:22,267 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-02-11 14:16:22,268 INFO sqlalchemy.engine.base.Engine {'table_oid': 16517}
# 2021-02-11 14:16:22,270 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-02-11 14:16:22,271 INFO sqlalchemy.engine.base.Engine {'table_oid': 16517}
# 2021-02-11 14:16:22,273 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
# 2021-02-11 14:16:22,274 INFO sqlalchemy.engine.base.Engine {'table': 16517}
# 2021-02-11 14:16:22,276 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2021-02-11 14:16:22,277 INFO sqlalchemy.engine.base.Engine {'table_oid': 16517}
# 2021-02-11 14:16:22,281 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-02-11 14:16:22,281 INFO sqlalchemy.engine.base.Engine {'table_oid': 16517}
# 2021-02-11 14:16:22,283 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2021-02-11 14:16:22,284 INFO sqlalchemy.engine.base.Engine {'table_oid': 16517}
# 2021-02-11 14:16:22,288 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-02-11 14:16:22,289 INFO sqlalchemy.engine.base.Engine {'table_oid': 16517}
# 2021-02-11 14:16:22,296 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-02-11 14:16:22,297 INFO sqlalchemy.engine.base.Engine {'table_name': 'suppliers'}
# 2021-02-11 14:16:22,300 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               a.attgenerated as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-02-11 14:16:22,301 INFO sqlalchemy.engine.base.Engine {'table_oid': 16506}
# 2021-02-11 14:16:22,303 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-02-11 14:16:22,304 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:16:22,307 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-02-11 14:16:22,307 INFO sqlalchemy.engine.base.Engine {}
# 2021-02-11 14:16:22,310 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-02-11 14:16:22,311 INFO sqlalchemy.engine.base.Engine {'table_oid': 16506}
# 2021-02-11 14:16:22,313 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-02-11 14:16:22,314 INFO sqlalchemy.engine.base.Engine {'table_oid': 16506}
# 2021-02-11 14:16:22,317 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2021-02-11 14:16:22,319 INFO sqlalchemy.engine.base.Engine {'table': 16506}
# 2021-02-11 14:16:22,326 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
# 2021-02-11 14:16:22,326 INFO sqlalchemy.engine.base.Engine {'table_oid': 16506}
# 2021-02-11 14:16:22,333 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-02-11 14:16:22,334 INFO sqlalchemy.engine.base.Engine {'table_oid': 16506}
# 2021-02-11 14:16:22,337 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2021-02-11 14:16:22,337 INFO sqlalchemy.engine.base.Engine {'table_oid': 16506}
# 2021-02-11 14:16:22,340 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-02-11 14:16:22,341 INFO sqlalchemy.engine.base.Engine {'table_oid': 16506}
# 2021-02-11 14:16:22,343 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2021-02-11 14:16:22,343 INFO sqlalchemy.engine.base.Engine {'table_oid': 16581}
# 2021-02-11 14:16:22,347 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-02-11 14:16:22,348 INFO sqlalchemy.engine.base.Engine {'table_oid': 16581}
# 2021-02-11 14:16:22,349 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2021-02-11 14:16:22,350 INFO sqlalchemy.engine.base.Engine {'table_oid': 16581}
# 2021-02-11 14:16:22,353 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-02-11 14:16:22,354 INFO sqlalchemy.engine.base.Engine {'table_oid': 16581}
# 2021-02-11 14:16:22,357 INFO sqlalchemy.engine.base.OptionEngine SELECT products.product_id, products.product_name, products.supplier_id, products.category_id, products.quantity_per_unit, products.unit_price, products.units_in_stock, products.reorder_level, products.units_on_order, products.discontinued
# FROM products
# 2021-02-11 14:16:22,358 INFO sqlalchemy.engine.base.OptionEngine {}

# %%
products.head()
# Out:
#    product_id                  product_name  supplier_id  category_id  \
# 0           1                          Chai            1            1
# 1           2                         Chang            1            1
# 2           3                 Aniseed Syrup            1            2
# 3           4  Chef Anton's Cajun Seasoning            2            2
# 4           5        Chef Anton's Gumbo Mix            2            2
#
#      quantity_per_unit  unit_price  units_in_stock  reorder_level  \
# 0   10 boxes x 20 bags       18.00              39              0
# 1   24 - 12 oz bottles       19.00              17             40
# 2  12 - 550 ml bottles       10.00              13             70
# 3       48 - 6 oz jars       22.00              53              0
# 4             36 boxes       21.35               0              0
#
#    units_on_order  discontinued
# 0              10             0
# 1              25             0
# 2              25             0
# 3               0             0
# 4               0             1

# %%
companies = pd.read_sql_query('SELECT company_name FROM customers', con=engine)
# Out:
# 2021-02-11 14:17:37,178 INFO sqlalchemy.engine.base.OptionEngine SELECT company_name FROM customers
# 2021-02-11 14:17:37,179 INFO sqlalchemy.engine.base.OptionEngine {}

# %%
companies
# Out:
#                           company_name
# 0                  Alfreds Futterkiste
# 1   Ana Trujillo Emparedados y helados
# 2              Antonio Moreno Taquería
# 3                      Around the Horn
# 4                   Berglunds snabbköp
# ..                                 ...
# 86                      Wartian Herkku
# 87              Wellington Importadora
# 88                White Clover Markets
# 89                         Wilman Kala
# 90                      Wolski  Zajazd
#
# [91 rows x 1 columns]

# %% [markdown]
# ### Direct SQL changes in the database
#
# We can use the SQL queries directly with the engine.execute instead of working with Pandas. When you have a lot of data and relatively simple operations, this is the better option. Because it is faster.

# %% [markdown]
# Let's write our join operation from this morning again.

# %% [markdown]
# References:
#
# This is a good source when you have a bit more time to read on SQLAlchemy: https://docs.sqlalchemy.org/en/13/core/engines.html
#
# Schema information for POSTGRESQL: https://www.postgresqltutorial.com/postgresql-schema/
# https://www.postgresql.org/docs/9.1/ddl-schemas.html
