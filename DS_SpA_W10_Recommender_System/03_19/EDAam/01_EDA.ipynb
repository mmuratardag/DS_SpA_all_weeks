# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/df.csv', na_values=[' '])
df.head()
# Out:
#    userId  movieId  rating                        title            title_only  \
# 0       1        1     4.0             Toy Story (1995)            Toy Story
# 1       1        3     4.0      Grumpier Old Men (1995)     Grumpier Old Men
# 2       1        6     4.0                  Heat (1995)                 Heat
# 3       1       47     5.0  Seven (a.k.a. Se7en) (1995)                Seven
# 4       1       50     5.0   Usual Suspects, The (1995)  Usual Suspects, The
#
#       Genre0     Genre1    Genre2  Genre3   Genre4 Genre5
# 0  Adventure  Animation  Children  Comedy  Fantasy    NaN
# 1     Comedy    Romance       NaN     NaN      NaN    NaN
# 2     Action      Crime  Thriller     NaN      NaN    NaN
# 3    Mystery   Thriller       NaN     NaN      NaN    NaN
# 4      Crime    Mystery  Thriller     NaN      NaN    NaN

# %%
# df['Genre0'].nunique() # 19

# %%
# what is the average rating?
# df['rating'].mean() # 3.501556983616962
# df['rating'].median() # 3.5

# %%
# df.groupby('Genre0')['rating'].mean()

# (no genres listed)    3.489362
# Action                3.447984
# Adventure             3.566029
# Animation             3.578266
# Children              3.153553
# Comedy                3.393901
# Crime                 3.834191
# Documentary           3.829557
# Drama                 3.647205
# Fantasy               3.496825
# Film-Noir             4.080357
# Horror                3.039821
# Musical               3.652985
# Mystery               3.855533
# Romance               3.104000
# Sci-Fi                3.460641
# Thriller              3.426752
# War                   3.555556
# Western               3.658940

# %%
df.groupby('Genre0')['rating'].mean().plot(kind = 'bar', figsize=(20, 5))
# Out:
# <AxesSubplot:xlabel='Genre0'>

# %%
# df['Genre0'].mode() # Action ## 3.447984
# df['Genre1'].mode() # Drama ## 3.647205
# df['Genre2'].mode() # Thriller ## 3.426752

# %%
# what is the average number of ratings?
# df.groupby('movieId')['userId'].nunique().mean() # 10.369806663924312

# %%
df['rating'].hist();

# %%
# how is the number of ratings per user distributed? ### ??????
df.groupby('userId')['rating'].hist(alpha=0.3);

# %%
# how is the number of ratings per movie distributed?
# df.groupby('movieId')['userId'].nunique().min() ## 1
# df.groupby('movieId')['userId'].nunique().max() ## 329
df.groupby('movieId')['userId'].nunique().hist(bins = 500)
# Out:
# <AxesSubplot:>

# %%
df[['movieId', 'title', 'title_only',]].drop_duplicates().to_csv('data/df_movieId_unique_title.csv', index=False)
